# %% [markdown]
# <meta property='og:image' content='https://www.information-age.com/wp-content/uploads/2018/11/data-era-1013x440.jpeg'>

# %% [markdown]
# ![](https://www.information-age.com/wp-content/uploads/2018/11/data-era-1013x440.jpeg)

# %% [markdown]
# <h1><center> Crime & Economy (in python) </center></h1>
#
# In this project I look for a relationship between economic data and crime rates.
#
# I obtained statistics for various industries at the county level from the Bureau of Labor Statistics. I also found the number of arrests and charges for a variety of crimes at the county level from the Inter-University Consortium for Political and Social Research. These datasets span from 2009, 2010, 2012, 2014, and 2016.
#
# After cleaning the data I will test out some statistical analysis.
#
# \---------------------------------------------------------------------------
#
# BLS, link to data: https://www.bls.gov/cew/datatoc.htm
#
# ICPSR / Crime, link to data: https://www.icpsr.umich.edu/icpsrweb/NACJD/series/57 (seires name: "Uniform Crime Reporting Program Data: County-Level Detailed Arrest and Offense Data, United States, yyyy")
#
# Authors Linkedin: https://www.linkedin.com/in/matt-krieger-094/

# %%
# Project
# %run Imports.ipynb
# Imports functions from seperate notebook
# %run Functions.ipynb
# Out:
# C:\Users\Matt\Documents\Projects\Python\Data and First Regress

# %% [markdown]
# Here I load in the data and spit out some summary statistics on the structure of the data.

# %%
# Reading in Data
start_time = timeit.default_timer()
# Keys to extract formatted State and County names
key00 = pd.read_csv('FIPS_countycodes.txt',delimiter=',')  # Counties only
key00['GU Name'] = key00['GU Name'].str[:-7]  # Slice 'county' from names
# Crime
crime2009 = pd.read_csv('30763-0001-crimedata2009.txt',delimiter='\t').fillna(0)
crime2009['year'] = 2009
crime2010 = pd.read_csv('33523-0001-crimedata2010.txt',delimiter='\t').fillna(0)
crime2010['year'] = 2010
crime2012 = pd.read_csv('35019-0001-crimedata2012.txt',delimiter='\t').fillna(0)
crime2012['year'] = 2012
crime2014 = pd.read_csv('36399-0001-crimedata2014.txt',delimiter='\t').fillna(0)
crime2014['year'] = 2014
crime2016 = pd.read_csv('37059-0001-crimedata2016.txt',delimiter='\t').fillna(0)
crime2016['year'] = 2016
# Enumployment & Wages
wage_unemp2018 = pd.read_csv('allhlcn183wage_unemp2018.txt',delimiter='\t',dtype={'St':str})
wage_unemp2016 = pd.read_csv('allhlcn163wage_unemp2016.txt',delimiter='\t',dtype={'St':str})
wage_unemp2014 = pd.read_csv('allhlcn143wage_unemp2014.txt',delimiter='\t',dtype={'St':str})
wage_unemp2012 = pd.read_csv('allhlcn123wage_unemp2012.txt',delimiter='\t',dtype={'St':str})
wage_unemp2010 = pd.read_csv('allhlcn103wage_unemp2010.txt',delimiter='\t',dtype={'St':str})
wage_unemp2009 = pd.read_csv('allhlcn091wage_unemp2009.txt',delimiter='\t',dtype={'St':str})
# allhlcn093wage_unemp2009.txt
elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
# Out:
# 2.959 run time

# %%
# Merge & clean all economic data
start_time = timeit.default_timer()
pd.options.mode.chained_assignment = None # Turn off copy with setting warning
econ00 = pd.concat([wage_unemp2009,wage_unemp2010,wage_unemp2012,wage_unemp2014,wage_unemp2016],0,sort=False)
econ01 = wage_cleaner(econ00)
# Get columns for bot to convert floats into ints
z = econ01.columns.tolist()
y = z[-8:]
econ02 = bot97(econ01)
# Merge & clean all criminal data
crime00 = pd.concat([crime2009,crime2010,crime2012,crime2014,crime2016],0,sort=False)
crime01 = crime_cleaner(crime00)
crime01 = crime01.drop([15681,15682,15683,15684,15685]) # drop counties only existing in one year (by index)
# Merge economic & criminal data
db = crime01.merge(econ02,left_on=['State Abbreviation','GU Name','year'],right_on=['State Abbreviation','GU Name','Year'])
cols = db.columns.tolist()
cols = cols[:3]+cols[49:]+cols[3:48]
db = db[cols]
elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
# Out:
# 9.454 run time

# %% [markdown]
# Here I generate a sample dataset of randomly selected counties and all associated data.

# %%
start_time = timeit.default_timer()
names = db.drop_duplicates(subset=['GU Name','State Abbreviation']) # Min df to pull names from
samp_db = {}
for a in range(200):
    i = random.randint(0,len(names))
    x = names['State Abbreviation'].iloc[i] # Pull State Abreviation
    y = names['GU Name'].iloc[i]  # Pull analogous county name
    z = x+', '+y # Format name for dictionary key
    data = db.loc[(db['State Abbreviation'] == x) & (db['GU Name'] == y)]
    samp_db[z] = data
keys = list(samp_db.keys())
print(len(samp_db.keys()))
print(samp_db.keys())
elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
# Out:
# 193
# dict_keys(['GA, Lanier', 'GA, Atkinson', 'AR, Woodruff', 'UT, Wayne', 'WI, Douglas', 'VA, Hopewe', 'IA, Lucas', 'TX, Chambers', 'AR, Lincoln', 'OK, Kiowa', 'TX, Gillespie', 'MO, Macon', 'NM, San Juan', 'TX, Hill', 'CO, Weld', 'NY, Tioga', 'IL, Cumberland', 'CO, Elbert', 'MS, Alcorn', 'AR, Drew', 'OH, Washington', 'VA, Orange', 'WY, Hot Springs', 'PA, Adams', 'NH, Merrimack', 'SC, Darlington', 'IA, Clay', 'AK, Ketchikan Gateway ', 'CO, Mineral', 'GA, Newton', 'NE, Valley', 'CO, Adams', 'AR, Stone', 'NE, Morrill', 'VA, Bedford', 'TX, Palo Pinto', 'MN, Wadena', 'NC, Halifax', 'IA, Mitchell', 'KS, Saline', 'TX, Kerr', 'SC, Pickens', 'MS, Issaquena', 'SC, Barnwell', 'TX, Polk', 'NY, Queens', "MD, St. Mary's", 'CA, Imperial', 'PA, Perry', 'FL, Baker', 'TX, Titus', 'KY, Bell', 'IN, Vigo', 'WI, Rusk', 'FL, Pinellas', 'TX, Brooks', 'TN, Greene', 'NE, Custer', 'OK, Comanche', 'WI, Washburn', 'KS, Montgomery', 'OH, Henry', 'OH, Madison', 'LA, Claiborne', 'SD, Bennett', 'WV, Braxton', 'TN, Tipton', 'MO, Montgomery', 'SD, Jerauld', 'ND, Sheridan', 'PA, Fulton', 'MT, Garfield', 'NC, Hyde', 'KY, Owen', 'IA, Allamakee', 'TX, DeWitt', 'NC, Edgecombe', 'WV, Grant', 'ND, Pierce', 'AR, Hot Spring', 'OH, Scioto', 'WV, Pocahontas', 'MO, Knox', 'IA, Ida', 'IA, Tama', 'MO, Ripley', 'IN, Perry', 'SC, Dillon', 'SC, Williamsburg', 'IL, Alexander', 'UT, Utah', 'IN, Wayne', 'OK, Oklahoma', 'MO, Cass', 'ID, Elmore', 'IA, Story', 'IL, Wayne', 'KS, Jewell', 'TX, Rockwall', 'TX, Val Verde', 'GA, Screven', 'CA, San Joaquin', 'MD, Calvert', 'IN, Ohio', 'KY, Henry', 'KS, Franklin', 'IA, Muscatine', 'CO, Las Animas', 'MN, Blue Earth', 'AK, Aleutians East ', 'CO, Delta', 'GA, Liberty', 'SD, Marshall', 'MO, Platte', 'CO, Pitkin', 'WY, Niobrara', 'VA, Wythe', 'MN, Koochiching', 'MO, Osage', 'KY, Clark', 'SD, Beadle', 'NC, Granville', 'MN, Cook', 'SD, Hamlin', 'IL, Bureau', 'LA, Iberia', 'NC, Anson', 'SD, Perkins', 'MI, St. Joseph', 'TX, Maverick', 'IN, Pike', 'IN, Martin', 'IL, De Witt', 'WI, Oneida', 'FL, Seminole', 'WI, Columbia', 'WA, Clallam', 'NC, Rockingham', 'WA, Whatcom', 'GA, Calhoun', 'IL, McHenry', 'CA, San Francisco', 'OH, Meigs', 'OR, Washington', 'TN, Knox', 'IL, Gallatin', 'KY, Hart', 'MS, Kemper', 'KY, Oldham', 'MO, Wright', 'WY, Natrona', 'TX, Collingsworth', 'WY, Teton', 'MS, Monroe', 'CO, Broomfield', 'VA, Powhatan', 'IN, Hancock', 'KY, Boyle', 'OH, Lorain', 'TX, Martin', 'WI, Chippewa', 'SC, Dorchester', 'KY, Hancock', 'NC, Henderson', 'WY, Albany', 'TN, Haywood', 'ND, Billings', 'NE, Hitchcock', 'NC, Caswell', 'IN, Marion', 'OK, Major', 'FL, Palm Beach', 'NE, Saunders', 'PA, Bedford', 'AR, Polk', 'WV, Lewis', 'MT, Valley', 'TN, Henry', 'KY, Metcalfe', 'AL, Cherokee', 'MO, Grundy', 'MN, Jackson', 'GA, Washington', 'GA, Oconee', 'NY, Ontario', 'NY, Rensselaer', 'AZ, Santa Cruz', 'NM, San Miguel', 'GA, Rabun', 'MI, Clinton', 'KS, Doniphan', 'KY, Christian', 'PA, Franklin'])
# 14.95 run time

# %%
# Select 5 biggest industries in sample
industry = big_industry_bot(samp_db)
print('5 Largest Industries in sample:\n',industry)
# Out:
# 5 Largest Industries in sample:
#  ['Goods-producing', 'Service-providing', 'Trade, transportation, and utilities', 'Financial activities', 'Other services']

# %%
# start base data frame -- create new dataframe, still need to account for various industries
start_time = timeit.default_timer()
bedrock = samp_db # Initialize sample to new variable for trouble shooting // preserve OG sample data
new_world = pd.DataFrame() # empty dataframe

for a in keys:
    for b in industry[:]:
        x = bedrock[a].loc[bedrock[a]['Industry'] == b] # Pull
        new_world = new_world.append(x)
        
new_world = new_world.reset_index()  # reset index
new_world = new_world.drop('index',axis=1)  # drop index column
cols = new_world.columns.tolist()
cols = cols[:3]+cols[7:]
new_world = new_world[cols]

elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
new_world.head(10)
# Out:
# 11.119 run time
#    year State Abbreviation GU Name           Industry  Establishment Count  \
# 0  2009                 GA  Lanier    Goods-producing                   31
# 1  2010                 GA  Lanier    Goods-producing                   36
# 2  2012                 GA  Lanier    Goods-producing                   30
# 3  2014                 GA  Lanier    Goods-producing                   31
# 4  2016                 GA  Lanier    Goods-producing                   34
# 5  2009                 GA  Lanier  Service-providing                   89
# 6  2010                 GA  Lanier  Service-providing                   89
# 7  2012                 GA  Lanier  Service-providing                   80
# 8  2014                 GA  Lanier  Service-providing                   76
# 9  2016                 GA  Lanier  Service-providing                   74
#
#    July Employment  August Employment  September Employment  \
# 0              NaN                NaN                   NaN
# 1            242.0              258.0                 206.0
# 2            371.0              353.0                 367.0
# 3            397.0              407.0                 411.0
# 4            578.0              572.0                 531.0
# 5              NaN                NaN                   NaN
# 6            674.0              632.0                 678.0
# 7            669.0              659.0                 650.0
# 8            579.0              459.0                 435.0
# 9            490.0              492.0                 496.0
#
#    Total Quarterly Wages  Average Weekly Wage  ...  OFAGFAM  DUI  LIQUOR  \
# 0              1498548.0                  525  ...       14   25       5
# 1              1709682.0                  559  ...        9   43       6
# 2              1761634.0                  373  ...        5   13       1
# 3              2002316.0                  380  ...       10   10       0
# 4              2491727.0                  342  ...        7   15       1
# 5              3664426.0                  459  ...       14   25       5
# 6              4088526.0                  476  ...        9   43       6
# 7              4489985.0                  524  ...        5   13       1
# 8              3164830.0                  496  ...       10   10       0
# 9              3270943.0                  511  ...        7   15       1
#
#    DRUNK  DISORDR  VAGRANT  ALLOTHR  SUSPICN  CURFEW  RUNAWAY
# 0      3       15        1      146        0       0        1
# 1      4       18        1      259        0       0        1
# 2      0        2        0       77        0       0        2
# 3      0        3        0       71        0       0        1
# 4      0        2        0       51        0       0        1
# 5      3       15        1      146        0       0        1
# 6      4       18        1      259        0       0        1
# 7      0        2        0       77        0       0        2
# 8      0        3        0       71        0       0        1
# 9      0        2        0       51        0       0        1
#
# [10 rows x 57 columns]

# %% [markdown]
# Due to inconsistencies in the data it is important that we double check that there is the same number of data entries for each industry we want to observe. If we have an uneven database, we need to draw a new sample.

# %%
# Check counts of target data to ensure symmetry/integrity for analysis
new_world = bot98(new_world,industry)  # Call function to check data
new_world
# Out:
# Count of target industries in sample
#
#  MUST ALL BE SAME
#
# Check
# Check
# Check
# Failed Industry Count Check
# Failed Industry Count Check
#
#
# Data is asymmetrical, searching for and dropping uneven data...
# Counties with corrupted data:  ['MT, Garfield', 'UT, Wayne']
#       year State Abbreviation   GU Name         Industry  Establishment Count  \
# 0     2009                 GA    Lanier  Goods-producing                   31
# 1     2010                 GA    Lanier  Goods-producing                   36
# 2     2012                 GA    Lanier  Goods-producing                   30
# 3     2014                 GA    Lanier  Goods-producing                   31
# 4     2016                 GA    Lanier  Goods-producing                   34
# ...    ...                ...       ...              ...                  ...
# 4818  2009                 PA  Franklin   Other services                  322
# 4819  2010                 PA  Franklin   Other services                  310
# 4820  2012                 PA  Franklin   Other services                  323
# 4821  2014                 PA  Franklin   Other services                  307
# 4822  2016                 PA  Franklin   Other services                  318
#
#       July Employment  August Employment  September Employment  \
# 0                 NaN                NaN                   NaN
# 1               242.0              258.0                 206.0
# 2               371.0              353.0                 367.0
# 3               397.0              407.0                 411.0
# 4               578.0              572.0                 531.0
# ...               ...                ...                   ...
# 4818              NaN                NaN                   NaN
# 4819           1826.0             1800.0                1768.0
# 4820           1845.0             1847.0                1873.0
# 4821           1832.0             1842.0                1866.0
# 4822           1953.0             1908.0                1959.0
#
#       Total Quarterly Wages  Average Weekly Wage  ...  OFAGFAM  DUI  LIQUOR  \
# 0                 1498548.0                  525  ...       14   25       5
# 1                 1709682.0                  559  ...        9   43       6
# 2                 1761634.0                  373  ...        5   13       1
# 3                 2002316.0                  380  ...       10   10       0
# 4                 2491727.0                  342  ...        7   15       1
# ...                     ...                  ...  ...      ...  ...     ...
# 4818              8445693.0                  352  ...       15  912     263
# 4819              9488084.0                  406  ...        9  902     190
# 4820              9987608.0                  414  ...        8  827     159
# 4821             10092854.0                  420  ...       12  630      97
# 4822             11406907.0                  452  ...       12  763      46
#
#       DRUNK  DISORDR  VAGRANT  ALLOTHR  SUSPICN  CURFEW  RUNAWAY
# 0         3       15        1      146        0       0        1
# 1         4       18        1      259        0       0        1
# 2         0        2        0       77        0       0        2
# 3         0        3        0       71        0       0        1
# 4         0        2        0       51        0       0        1
# ...     ...      ...      ...      ...      ...     ...      ...
# 4818    229      564        1      455        0      41       72
# 4819    251      605       11      409        0      46       74
# 4820    237      400        6      437        0      46       70
# 4821    207      256        3      402        0      50       75
# 4822    154      188        1      383        0      10       63
#
# [4775 rows x 57 columns]

# %% [markdown]
# In order to account for changes in population size, we must convert all of our data into percentage changes from a base year (2009). This transformation will cause us to lose a year of data entries but will provide a more robust model.

# %%
# Convert dataframe into percent changes
start_time = timeit.default_timer()
z = new_world.columns.tolist()
a = new_world[z[:4]] # Split names and catagories off of dataframe;; Quicker runtime
b = new_world[z[4:]] # Split numbers into seperate dataframe for percentage changes
tail = 0
head = 5
# .iloc using loop to apply percent change for every 5 years
for i in range(int(len(b)/5)):
    b.iloc[tail:head] = b.iloc[tail:head][:].pct_change()
    head += 5                                
    tail += 5
new_world = pd.concat([a,b],1) # Recombind dataframes
elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
# Out:
# 28.775 run time

# %%
new_world
# Out:
#       year State Abbreviation   GU Name         Industry  Establishment Count  \
# 0     2009                 GA    Lanier  Goods-producing                  NaN
# 1     2010                 GA    Lanier  Goods-producing             0.161290
# 2     2012                 GA    Lanier  Goods-producing            -0.166667
# 3     2014                 GA    Lanier  Goods-producing             0.033333
# 4     2016                 GA    Lanier  Goods-producing             0.096774
# ...    ...                ...       ...              ...                  ...
# 4818  2009                 PA  Franklin   Other services                  NaN
# 4819  2010                 PA  Franklin   Other services            -0.037267
# 4820  2012                 PA  Franklin   Other services             0.041935
# 4821  2014                 PA  Franklin   Other services            -0.049536
# 4822  2016                 PA  Franklin   Other services             0.035831
#
#       July Employment  August Employment  September Employment  \
# 0                 NaN                NaN                   NaN
# 1                 NaN                NaN                   NaN
# 2            0.533058           0.368217              0.781553
# 3            0.070081           0.152975              0.119891
# 4            0.455919           0.405405              0.291971
# ...               ...                ...                   ...
# 4818              NaN                NaN                   NaN
# 4819              NaN                NaN                   NaN
# 4820         0.010405           0.026111              0.059389
# 4821        -0.007046          -0.002707             -0.003737
# 4822         0.066048           0.035831              0.049839
#
#       Total Quarterly Wages  Average Weekly Wage  ...   OFAGFAM       DUI  \
# 0                       NaN                  NaN  ...       NaN       NaN
# 1                  0.140892             0.064762  ... -0.357143  0.720000
# 2                  0.030387            -0.332737  ... -0.444444 -0.697674
# 3                  0.136624             0.018767  ...  1.000000 -0.230769
# 4                  0.244422            -0.100000  ... -0.300000  0.500000
# ...                     ...                  ...  ...       ...       ...
# 4818                    NaN                  NaN  ...       NaN       NaN
# 4819               0.123423             0.153409  ... -0.400000 -0.010965
# 4820               0.052648             0.019704  ... -0.111111 -0.083149
# 4821               0.010538             0.014493  ...  0.500000 -0.238210
# 4822               0.130196             0.076190  ...  0.000000  0.211111
#
#         LIQUOR     DRUNK   DISORDR    VAGRANT   ALLOTHR  SUSPICN    CURFEW  \
# 0          NaN       NaN       NaN        NaN       NaN      NaN       NaN
# 1     0.200000  0.333333  0.200000   0.000000  0.773973      NaN       NaN
# 2    -0.833333 -1.000000 -0.888889  -1.000000 -0.702703      NaN       NaN
# 3    -1.000000       NaN  0.500000        NaN -0.077922      NaN       NaN
# 4          inf       NaN -0.333333        NaN -0.281690      NaN       NaN
# ...        ...       ...       ...        ...       ...      ...       ...
# 4818       NaN       NaN       NaN        NaN       NaN      NaN       NaN
# 4819 -0.277567  0.096070  0.072695  10.000000 -0.101099      NaN  0.121951
# 4820 -0.163158 -0.055777 -0.338843  -0.454545  0.068460      NaN  0.000000
# 4821 -0.389937 -0.126582 -0.360000  -0.500000 -0.080092      NaN  0.086957
# 4822 -0.525773 -0.256039 -0.265625  -0.666667 -0.047264      NaN -0.800000
#
#        RUNAWAY
# 0          NaN
# 1     0.000000
# 2     1.000000
# 3    -0.500000
# 4     0.000000
# ...        ...
# 4818       NaN
# 4819  0.027778
# 4820 -0.054054
# 4821  0.071429
# 4822 -0.160000
#
# [4775 rows x 57 columns]

# %%
# Create final data frame that accounts for metrics across industries
start_time = timeit.default_timer()
samp_dic = {}
stat = ['Establishment Count','Average Weekly Wage','August Employment']
# Pull and reformat target stats and industries
for s in stat:
    for n in industry:
        samp_dic[n+' '+s] = test_func(new_world,keys,s,n)
# Convert dictionary to data frame  
finaldb = pd.DataFrame(data=samp_dic)
# labels for rematching
labels = new_world[['year','State Abbreviation','GU Name']].drop_duplicates(subset=['State Abbreviation','GU Name','year'])
# Split off crime data
crimedb = new_world.drop_duplicates(subset=['State Abbreviation','GU Name','year'])
cols = crimedb.columns.tolist()
crimedb = crimedb[cols[12:]] # Select only crime columns
# Apply labels to crime and econ data
crime = pd.concat([labels,crimedb],1)
econ = pd.concat([labels,finaldb],1)
finaldb = econ.merge(crime,left_on=['State Abbreviation','GU Name','year'],right_on=['State Abbreviation','GU Name','year'])
finaldb['year'] = finaldb['year'].astype(int) # convert year from float to int
#print(samp_dic.keys(),'\n\n')
# Remove NAs and infinite values
cols = finaldb.columns.tolist()
finaldb[cols[18:]] = finaldb[cols[18:]].fillna(0) # Fill all NaNs with 0's in crime data(because cannot divide by zero)
finaldb = finaldb.dropna(how='any').replace(-np.inf,-0.99).replace(np.inf,0.99)  # drop all 2010/base year data
elapsed = timeit.default_timer() - start_time
print(round(elapsed,3),'run time')
finaldb
# Out:
# 0.123 run time
#      year State Abbreviation   GU Name  Service-providing Establishment Count  \
# 2    2012                 WI      Dunn                               0.023148
# 3    2014                 WI      Dunn                              -0.060332
# 4    2016                 WI      Dunn                               0.088283
# 7    2012                 KS       Elk                               0.021935
# 8    2014                 KS       Elk                              -0.003157
# ..    ...                ...       ...                                    ...
# 188  2014                 MT     Toole                              -0.006386
# 189  2016                 MT     Toole                              -0.023136
# 192  2012                 FL  Franklin                               0.023093
# 193  2014                 FL  Franklin                               0.015223
# 194  2016                 FL  Franklin                               0.038263
#
#      Trade, transportation, and utilities Establishment Count  \
# 2                                             0.025907
# 3                                            -0.025253
# 4                                             0.062176
# 7                                            -0.015119
# 8                                             0.004386
# ..                                                 ...
# 188                                           0.015209
# 189                                          -0.041199
# 192                                          -0.028463
# 193                                           0.019531
# 194                                           0.017241
#
#      Leisure and hospitality Establishment Count  \
# 2                                      -0.025424
# 3                                      -0.060870
# 4                                       0.120370
# 7                                       0.042969
# 8                                      -0.048689
# ..                                           ...
# 188                                     0.055556
# 189                                    -0.021053
# 192                                     0.032432
# 193                                     0.000000
# 194                                     0.015707
#
#      Financial activities Establishment Count  \
# 2                                    0.123077
# 3                                   -0.082192
# 4                                   -0.044776
# 7                                   -0.043902
# 8                                    0.010204
# ..                                        ...
# 188                                 -0.068493
# 189                                 -0.014706
# 192                                 -0.018750
# 193                                  0.012739
# 194                                  0.025157
#
#      Goods-producing Establishment Count  \
# 2                              -0.005208
# 3                               0.020942
# 4                               0.000000
# 7                              -0.032558
# 8                              -0.021635
# ..                                   ...
# 188                             0.000000
# 189                             0.062500
# 192                             0.022843
# 193                            -0.007444
# 194                             0.022500
#
#      Service-providing Average Weekly Wage  \
# 2                                 0.065789
# 3                                 0.063492
# 4                                 0.072968
# 7                                 0.073930
# 8                                 0.085145
# ..                                     ...
# 188                               0.016304
# 189                               0.099822
# 192                               0.035471
# 193                               0.083004
# 194                               0.093674
#
#      Trade, transportation, and utilities Average Weekly Wage  ...   OFAGFAM  \
# 2                                             0.059190         ... -0.555556
# 3                                             0.052941         ...  1.250000
# 4                                            -0.018156         ...  0.888889
# 7                                             0.054217         ...  0.000000
# 8                                             0.112381         ...  0.000000
# ..                                                 ...         ...       ...
# 188                                           0.044944         ...  0.000000
# 189                                           0.053763         ...  0.000000
# 192                                          -0.045662         ...  0.000000
# 193                                           0.065391         ...  0.000000
# 194                                           0.062874         ...  0.000000
#
#           DUI    LIQUOR  DRUNK   DISORDR  VAGRANT   ALLOTHR  SUSPICN  CURFEW  \
# 2   -0.391720 -0.294974    0.0 -0.235294    -1.00 -0.076398      0.0     0.0
# 3    0.335079  0.103189    0.0 -0.036789     0.99 -0.169867      0.0     0.0
# 4    0.011765 -0.207483    0.0 -0.093750     0.00 -0.010676      0.0     0.0
# 7   -0.400000  0.000000    0.0  1.000000     0.00  5.000000      0.0     0.0
# 8   -0.833333 -0.500000    0.0 -0.500000     0.00 -0.388889      0.0     0.0
# ..        ...       ...    ...       ...      ...       ...      ...     ...
# 188  0.636364  4.500000    0.0 -0.222222     0.00  0.100000      0.0     0.0
# 189  0.111111 -0.181818    0.0 -0.571429     0.00  0.545455      0.0     0.0
# 192  0.000000  0.000000    0.0  0.000000     0.00  0.000000      0.0     0.0
# 193  0.000000  0.000000    0.0  0.000000     0.00  0.000000      0.0     0.0
# 194  0.000000  0.000000    0.0  0.000000     0.00  0.000000      0.0     0.0
#
#       RUNAWAY
# 2    0.990000
# 3   -0.333333
# 4   -0.500000
# 7    0.000000
# 8    0.000000
# ..        ...
# 188  0.000000
# 189  0.000000
# 192  0.000000
# 193  0.000000
# 194  0.000000
#
# [116 rows x 63 columns]

# %% [markdown]
# # Statistical Analysis

# %%
corrdb = finaldb.corr().abs().sum()
corrdbl = pd.DataFrame(data=corrdb).nlargest(11,0).transpose()  # Largest correlations
corrdbs = pd.DataFrame(data=corrdb).nsmallest(10,0).transpose()   # Smallest correlations
# Creates a correlation matrix of all variables
plt.matshow(finaldb.corr())
plt.suptitle('Correlation Matrix Of All Variables\n')
plt.show()
cols = finaldb.columns.tolist()
print('\n11 Highest total correlations:')
corrdbl
# Out:
# 11 Highest total correlations:
#     OTHASLT   ROBBERY     P1TOT   LARCENY   WEAPONS   P1PRPTY   SYNSALE  \
# 0  9.665837  9.020335  8.810022  8.676227  8.602259  8.555789  8.456213
#
#     VANDLSM   DRGPOSS   DISORDR     FRAUD
# 0  8.352354  8.341407  8.271634  8.028981

# %%
l = corrdbl.columns.tolist() # variables to regress on
exp = l[1:] # Selects variable with highest total correlation to use as dependant variable
dep = l[0] # Uses next 10 most correlated variables to act as independant variables

# %% [markdown]
# # REGRESSION
#
# Regression is of most correlated variable on next 10 most correlated variables

# %%
x = finaldb[exp]  # Select columns to use as independant vars
y = finaldb[dep]  # Set y variable

model = sm.OLS(y, x.astype(float)).fit()
predictions = model.predict(x) # make the predictions by the model

print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                OTHASLT   R-squared (uncentered):                   0.730
# Model:                            OLS   Adj. R-squared (uncentered):              0.705
# Method:                 Least Squares   F-statistic:                              28.68
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                    8.16e-26
# Time:                        16:03:16   Log-Likelihood:                         -64.016
# No. Observations:                 116   AIC:                                      148.0
# Df Residuals:                     106   BIC:                                      175.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ROBBERY        0.0118      0.036      0.330      0.742      -0.059       0.083
# P1TOT          0.2808      0.091      3.079      0.003       0.100       0.462
# LARCENY        0.3182      0.078      4.065      0.000       0.163       0.473
# WEAPONS        0.1251      0.059      2.131      0.035       0.009       0.242
# P1PRPTY       -0.2296      0.119     -1.931      0.056      -0.465       0.006
# SYNSALE        0.0047      0.035      0.137      0.891      -0.064       0.073
# VANDLSM       -0.0265      0.086     -0.309      0.758      -0.197       0.144
# DRGPOSS       -0.0267      0.052     -0.514      0.608      -0.130       0.076
# DISORDR        0.2469      0.036      6.833      0.000       0.175       0.319
# FRAUD          0.0725      0.063      1.150      0.253      -0.052       0.197
# ==============================================================================
# Omnibus:                       17.727   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.035
# Skew:                          -0.426   Prob(JB):                     3.04e-12
# Kurtosis:                       6.201   Cond. No.                         6.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Regression of most correlated variable on all economic variables

# %%
x = finaldb[finaldb.columns.tolist()[3:18]]  # Selects all economic variables
y = finaldb[dep]  # Set y variable

model = sm.OLS(y, x.astype(float)).fit()
predictions = model.predict(x) # make the predictions by the model

print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                OTHASLT   R-squared (uncentered):                   0.054
# Model:                            OLS   Adj. R-squared (uncentered):             -0.087
# Method:                 Least Squares   F-statistic:                             0.3809
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                       0.981
# Time:                        16:03:18   Log-Likelihood:                         -136.80
# No. Observations:                 116   AIC:                                      303.6
# Df Residuals:                     101   BIC:                                      344.9
# Df Model:                          15
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Service-providing Establishment Count                       -0.0185      2.361     -0.008      0.994      -4.703       4.666
# Trade, transportation, and utilities Establishment Count    -0.2672      1.823     -0.147      0.884      -3.883       3.349
# Leisure and hospitality Establishment Count                  0.6924      1.167      0.593      0.554      -1.623       3.007
# Financial activities Establishment Count                    -0.2147      1.039     -0.207      0.837      -2.277       1.847
# Goods-producing Establishment Count                         -0.0064      1.190     -0.005      0.996      -2.367       2.355
# Service-providing Average Weekly Wage                       -2.2744      2.092     -1.087      0.280      -6.425       1.876
# Trade, transportation, and utilities Average Weekly Wage     1.6769      1.742      0.963      0.338      -1.778       5.132
# Leisure and hospitality Average Weekly Wage                  0.0157      0.548      0.029      0.977      -1.071       1.102
# Financial activities Average Weekly Wage                     0.2162      0.694      0.312      0.756      -1.161       1.593
# Goods-producing Average Weekly Wage                          0.7032      0.982      0.716      0.475      -1.244       2.651
# Service-providing August Employment                          0.1736      1.652      0.105      0.917      -3.104       3.451
# Trade, transportation, and utilities August Employment       0.9685      1.199      0.808      0.421      -1.409       3.346
# Leisure and hospitality August Employment                    0.0527      0.289      0.182      0.856      -0.521       0.626
# Financial activities August Employment                       0.1365      0.476      0.287      0.775      -0.807       1.080
# Goods-producing August Employment                           -0.0943      0.343     -0.275      0.784      -0.775       0.586
# ==============================================================================
# Omnibus:                      144.948   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3823.865
# Skew:                           4.512   Prob(JB):                         0.00
# Kurtosis:                      29.640   Cond. No.                         18.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Regression Summary
#
# The first regression likely has the highest R-squared in our sample. Perhaps unsurprisingly we see that crime rates are more related to each other than with or between economic data. We also see that aggregate variables tend to be the strongest which makes sense again due to their interconnected nature.
#
#
#
#
# In the second regression we can see the most correlated crime rate (total part 1 crimes; an aggregate of murder, rape, robbery, aggravated assault, burglary, larceny, auto theft, and arson) regressed on all of our economic variables. It is a substantially lower R-squared value and is no longer significant.
